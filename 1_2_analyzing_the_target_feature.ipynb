# %% [markdown]
# Now comes the hard part. Analyzing the genres section. Unfortunately, pandas dataframes are not meant to hold lists, so we're going to need to be clever about this.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('7_final_books.csv').drop('Unnamed: 0', axis=1)
df = df[df['genre'] != '[]']

# %% [markdown]
# Some research on how to deal with this led me to this excellent article by Max Hilsdorf:
#
# https://towardsdatascience.com/dealing-with-list-values-in-pandas-dataframes-a177e534f173
#
# Let's try out some of his ideas.
#
# First, I need to see the formatting of my lists.

# %%
print(type(df.iloc[0]['genre']))
print(df.iloc[0]['genre'])
# Out:
# <class 'str'>
# ['Science Fiction', 'Fiction', 'Fantasy', 'Queer', 'LGBT', 'Adult', 'Time Travel']

# %% [markdown]
# As expected, pandas has put this lists into the form of a string. But there is one relief--each element is surrounded by quotation marks. That should make things a bit easier!

# %%
df['genre'] = df['genre'].apply(eval)

# %%
print(type(df.iloc[0]['genre']))
print(df.iloc[0]['genre'])
# Out:
# <class 'list'>
# ['Science Fiction', 'Fiction', 'Fantasy', 'Queer', 'LGBT', 'Adult', 'Time Travel']

# %% [markdown]
# Wonderful! Each book's genre feature is now treated as a list! Now we just need to find the counts--ideally without looping through all 22,000 data points. Hilsdorf recommends we consider the column as a 2D array, and then convert it to a 1D array.

# %%
def to_1D(series):
    return pd.Series([x for _list in series for x in _list])

# %%
all_genres = to_1D(df['genre'])

# %%
all_genres.head(10)
# Out:
# 0    Science Fiction
# 1            Fiction
# 2            Fantasy
# 3              Queer
# 4               LGBT
# 5              Adult
# 6        Time Travel
# 7    Science Fiction
# 8            Mystery
# 9            Fiction
# dtype: object

# %%
print(f"Our {len(df)} books have a total of {len(all_genres)} genres.\
 An average of {round(len(all_genres)/len(df), 1)} genres per book.")
# Out:
# Our 22022 books have a total of 131598 genres. An average of 6.0 genres per book.

# %% [markdown]
# Now that the genre column is correctly interpreted as a list, we can get more specific by adding a column for the number of genres each book has.

# %%
df['num genres'] = df['genre'].apply(lambda x: len(x))

# %%
df.head()
# Out:
#                                      title              author  total words
# 0                       The Vanished Birds       Simon Jimenez     124205.0  \
# 1                       The Price of Honor  Jonathan P. Brazee      77253.0
# 2  The Case of the Baker Street Irregulars     Anthony Boucher      80557.0
# 3                                  Wildoak    C. C. Harrington      55602.0
# 4                              The Holiday         T. M. Logan     101767.0
#
#    vividness  passive voice  all adverbs  ly-adverbs  non-ly-adverbs
# 0      55.18           6.37         1.95        0.36            1.58  \
# 1      35.35           8.71         2.63        0.71            1.92
# 2      32.33           8.41         3.72        1.64            2.08
# 3      74.34           6.92         3.04        1.16            1.87
# 4      50.30           8.02         3.06        1.12            1.93
#
#                                                genre    year  num genres
# 0  [Science Fiction, Fiction, Fantasy, Queer, LGB...  2020.0           7
# 1                                  [Science Fiction]  2017.0           1
# 2  [Mystery, Fiction, Crime, Humor, Classics, 20t...  1940.0           7
# 3  [Middle Grade, Historical Fiction, Fiction, An...  2022.0           7
# 4  [Thriller, Mystery, Fiction, Mystery Thriller,...  2019.0           7

# %% [markdown]
# Next, let's see which genres are most common. I know from inspection that many of the elements classed as genres are actually not categories that would generally be considered genres--elements like "Australia," or "Star Trek." I'd anticipate finding these near the bottom for number of books. This is likely because Goodreads genres are generated by how users shelve their own books.

# %%
len(all_genres.value_counts())
# Out:
# 688

# %% [markdown]
# All in all, we have nearly 700 supposed "genres!" Definitely too many to try to classify from only 22,000 books. Time to start finding ones to eliminate!

# %%
all_genres.value_counts().head()
# Out:
# Fiction      15167
# Mystery       7840
# Thriller      6067
# Fantasy       5670
# Audiobook     5477
# Name: count, dtype: int64

# %% [markdown]
# As it turns out, one of the top 5 "genres" is, in fact, not a genre--"Audiobook" is a format. It looks like not all the "genres" we need to get rid of will be close to the bottom!
#
# Still, it might be worth checking the singletons.

# %%
np.sum(all_genres.value_counts() == 1)
# Out:
# 117

# %% [markdown]
# It seems that over a hundred of the "genres" appear only once in the entire dataframe! Let's expand our net even more.

# %%
np.sum(all_genres.value_counts() <= 10)
# Out:
# 333

# %% [markdown]
# Wow! Just about half of the genres appear in fewer than 10 books.
#
# Out of curiosity, let's see what some of the singletons look like.

# %%
genres_df = pd.DataFrame(all_genres.value_counts())

# %%
genres_df[genres_df['count'] == 1].head(10)
# Out:
#                           count
# Mauritius                     1
# Paranormal Urban Fantasy      1
# Victorian Romance             1
# Transport                     1
# Wonder Woman                  1
# Romanian Literature           1
# Golden Age Mystery            1
# Romanticism                   1
# Spider Man                    1
# Georgian                      1

# %% [markdown]
# Here we can see locations, time periods, overly-specific combination genres, topics, and even two characters.

# %%
genres_df[genres_df['count'] == 1].tail(10)
# Out:
#                     count
# M M Sports Romance      1
# Mysticism               1
# Green                   1
# M M Mystery             1
# American Fiction        1
# Banks                   1
# Cthulhu Mythos          1
# Prayer                  1
# Bigfoot                 1
# Romania                 1

# %% [markdown]
# These patterns continue at the bottom of the list. None of these are good candidates for classification, and can easily be removed.
#
# Let's check genres with 10 books.

# %%
genres_df[genres_df['count'] == 10].head(10)
# Out:
#                   count
# Terrorism            10
# Academic             10
# Ecology              10
# Ukraine              10
# Birds                10
# Social Issues        10
# Category Romance     10
# Chapter Books        10
# Fitness              10
# Read For School      10

# %% [markdown]
# These do indeed follow similar patterns! Mostly topics, genres, formats, and "read for school," which is simply the way people shelve their books.
#
# Let's try approaching this from the opposite direciton. How many genres have at least 1000 books?

# %%
print(f"{len(genres_df[genres_df['count'] >= 1000])} genres have more than 1000 books.")
genres_df[genres_df['count'] >= 1000]
# Out:
# 27 genres have more than 1000 books.
#                          count
# Fiction                  15167
# Mystery                   7840
# Thriller                  6067
# Fantasy                   5670
# Audiobook                 5477
# Mystery Thriller          3934
# Crime                     3765
# Science Fiction           3483
# Contemporary              3328
# Romance                   3234
# Nonfiction                3106
# Suspense                  2937
# Historical Fiction        2917
# Adult                     2679
# Young Adult               2543
# Historical                1997
# Horror                    1595
# Adventure                 1343
# Paranormal                1301
# History                   1212
# Literary Fiction          1200
# Science Fiction Fantasy   1188
# Magic                     1131
# Novels                    1104
# Biography                 1077
# Classics                  1058
# LGBT                      1009

# %% [markdown]
# The most comon, by far, is Fiction, with more than half of our dataset. It could be argued whether this represents a "genre" at all, and it may or may not be a useful classification.
#
# "Audiobook" is certainly not a genre, and "Mystery Thriller" appears to be a combination of two larger genres, "Mystery" and "Thriller."

# %%
#Number of books with the genre "Mystery Thriller" (as seen above)
len(df[df['genre'].apply(lambda x: "Mystery Thriller" in x)])
# Out:
# 3934

# %%
#Number of books with both the genre "Mystery Thriller" and the genre "Mystery"
len(df[df['genre'].apply(lambda x: ("Mystery Thriller" in x) & ("Mystery" in x))])
# Out:
# 3774

# %%
#Number of books with both the genre "Mystery Thriller" and the genre "Thriller"
len(df[df['genre'].apply(lambda x: ("Mystery Thriller" in x) & ("Thriller" in x))])
# Out:
# 3342

# %%
#Number of books with all three genres, "Mystery Thriller", "Mystery", and "Thriller"
len(df[df['genre'].apply(lambda x: ("Mystery Thriller" in x) & ("Thriller" in x) & ("Mystery" in x))])
# Out:
# 3220

# %%
3220/3934
# Out:
# 0.8185053380782918

# %% [markdown]
# Sure enough, there's more than an 80% overlap in "Mystery Thriller" and both of the other genres. So "Mystery Thriller" is mostly redundant and can be removed--or at least replaced with both Mystery and Thriller.
#
# The rest require some domain knowledge. Is "Magic" a genre? Are "Novels" a genre seperate from Fiction? Are most of the books in other genres actually novels without mentioning it?
#
# It might be useful to check the correlations between these. Surely there's a way this can be done!

# %%
top_genres = genres_df[genres_df['count']>=1000].reset_index()

# %%
corr = np.ones(shape=(27,27))

# %%
for i in range(1, len(top_genres)):
    for j in range(i):
        genre_i = top_genres.iloc[i]['index']
        genre_j = top_genres.iloc[j]['index']
        count_i = len(df[df['genre'].apply(lambda x: genre_i in x)])
        count_j = len(df[df['genre'].apply(lambda x: genre_j in x)])
        count_both = len(df[df['genre'].apply(lambda x: (genre_i in x) & (genre_j in x))])
        corr[i][j] = count_both/count_i
        corr[j][i] = count_both/count_j

# %%
top_genres.iloc[0]['index']
# Out:
# 'Fiction'

# %%
corr = pd.DataFrame(corr)

# %%
corr.columns = top_genres['index']

# %%
corr.index = top_genres['index']

# %%
corr.style.background_gradient()
# Out:
# <style type="text/css">
# #T_766ff_row0_col0, #T_766ff_row1_col1, #T_766ff_row2_col2, #T_766ff_row3_col3, #T_766ff_row4_col4, #T_766ff_row5_col5, #T_766ff_row6_col6, #T_766ff_row7_col7, #T_766ff_row8_col8, #T_766ff_row9_col9, #T_766ff_row10_col10, #T_766ff_row11_col11, #T_766ff_row12_col12, #T_766ff_row13_col13, #T_766ff_row14_col14, #T_766ff_row15_col15, #T_766ff_row16_col16, #T_766ff_row17_col17, #T_766ff_row18_col18, #T_766ff_row19_col19, #T_766ff_row20_col20, #T_766ff_row21_col21, #T_766ff_row22_col22, #T_766ff_row23_col23, #T_766ff_row24_col24, #T_766ff_row25_col25, #T_766ff_row26_col26 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_766ff_row0_col1, #T_766ff_row18_col9 {
#   background-color: #89b1d4;
#   color: #000000;
# }
# #T_766ff_row0_col2 {
#   background-color: #acc0dd;
#   color: #000000;
# }
# #T_766ff_row0_col3, #T_766ff_row8_col4 {
#   background-color: #c6cce3;
#   color: #000000;
# }
# #T_766ff_row0_col4, #T_766ff_row25_col23 {
#   background-color: #d6d6e9;
#   color: #000000;
# }
# #T_766ff_row0_col5, #T_766ff_row8_col20, #T_766ff_row14_col1, #T_766ff_row17_col2, #T_766ff_row18_col16, #T_766ff_row20_col13 {
#   background-color: #d2d2e7;
#   color: #000000;
# }
# #T_766ff_row0_col6, #T_766ff_row4_col6, #T_766ff_row9_col13, #T_766ff_row23_col25 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_766ff_row0_col7, #T_766ff_row4_col11, #T_766ff_row23_col7 {
#   background-color: #dfddec;
#   color: #000000;
# }
# #T_766ff_row0_col8, #T_766ff_row3_col22, #T_766ff_row25_col7 {
#   background-color: #dcdaeb;
#   color: #000000;
# }
# #T_766ff_row0_col9, #T_766ff_row0_col13, #T_766ff_row7_col4, #T_766ff_row8_col23, #T_766ff_row12_col4, #T_766ff_row15_col13, #T_766ff_row21_col22 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_766ff_row0_col10, #T_766ff_row0_col19, #T_766ff_row0_col24, #T_766ff_row1_col19, #T_766ff_row1_col24, #T_766ff_row2_col10, #T_766ff_row2_col19, #T_766ff_row2_col22, #T_766ff_row2_col24, #T_766ff_row3_col10, #T_766ff_row3_col19, #T_766ff_row3_col24, #T_766ff_row5_col10, #T_766ff_row5_col19, #T_766ff_row5_col21, #T_766ff_row5_col22, #T_766ff_row5_col24, #T_766ff_row6_col21, #T_766ff_row6_col22, #T_766ff_row7_col10, #T_766ff_row7_col19, #T_766ff_row7_col24, #T_766ff_row8_col17, #T_766ff_row8_col19, #T_766ff_row8_col21, #T_766ff_row9_col19, #T_766ff_row10_col0, #T_766ff_row10_col1, #T_766ff_row10_col2, #T_766ff_row10_col3, #T_766ff_row10_col5, #T_766ff_row10_col7, #T_766ff_row10_col11, #T_766ff_row10_col12, #T_766ff_row10_col14, #T_766ff_row10_col16, #T_766ff_row10_col18, #T_766ff_row10_col20, #T_766ff_row10_col21, #T_766ff_row10_col22, #T_766ff_row10_col23, #T_766ff_row11_col10, #T_766ff_row11_col15, #T_766ff_row11_col19, #T_766ff_row11_col22, #T_766ff_row11_col24, #T_766ff_row11_col25, #T_766ff_row11_col26, #T_766ff_row12_col10, #T_766ff_row12_col19, #T_766ff_row12_col24, #T_766ff_row13_col25, #T_766ff_row14_col10, #T_766ff_row14_col19, #T_766ff_row14_col24, #T_766ff_row16_col24, #T_766ff_row18_col19, #T_766ff_row18_col20, #T_766ff_row18_col23, #T_766ff_row18_col24, #T_766ff_row18_col25, #T_766ff_row19_col0, #T_766ff_row19_col3, #T_766ff_row19_col5, #T_766ff_row19_col7, #T_766ff_row19_col8, #T_766ff_row19_col9, #T_766ff_row19_col11, #T_766ff_row19_col12, #T_766ff_row19_col14, #T_766ff_row19_col16, #T_766ff_row19_col18, #T_766ff_row19_col20, #T_766ff_row19_col21, #T_766ff_row19_col22, #T_766ff_row19_col23, #T_766ff_row20_col17, #T_766ff_row20_col18, #T_766ff_row20_col19, #T_766ff_row20_col21, #T_766ff_row20_col22, #T_766ff_row20_col24, #T_766ff_row21_col5, #T_766ff_row21_col6, #T_766ff_row21_col8, #T_766ff_row21_col10, #T_766ff_row21_col15, #T_766ff_row21_col19, #T_766ff_row21_col20, #T_766ff_row21_col24, #T_766ff_row22_col2, #T_766ff_row22_col5, #T_766ff_row22_col6, #T_766ff_row22_col11, #T_766ff_row22_col19, #T_766ff_row22_col20, #T_766ff_row22_col23, #T_766ff_row22_col24, #T_766ff_row22_col25, #T_766ff_row23_col10, #T_766ff_row23_col18, #T_766ff_row23_col19, #T_766ff_row23_col22, #T_766ff_row23_col24, #T_766ff_row24_col0, #T_766ff_row24_col1, #T_766ff_row24_col2, #T_766ff_row24_col3, #T_766ff_row24_col5, #T_766ff_row24_col7, #T_766ff_row24_col11, #T_766ff_row24_col12, #T_766ff_row24_col14, #T_766ff_row24_col16, #T_766ff_row24_col18, #T_766ff_row24_col20, #T_766ff_row24_col21, #T_766ff_row24_col22, #T_766ff_row24_col23, #T_766ff_row25_col4, #T_766ff_row25_col13, #T_766ff_row25_col22 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_766ff_row0_col11, #T_766ff_row4_col13, #T_766ff_row9_col18 {
#   background-color: #e0dded;
#   color: #000000;
# }
# #T_766ff_row0_col12, #T_766ff_row14_col8, #T_766ff_row14_col17 {
#   background-color: #e1dfed;
#   color: #000000;
# }
# #T_766ff_row0_col14, #T_766ff_row1_col8, #T_766ff_row3_col13, #T_766ff_row4_col7, #T_766ff_row7_col2, #T_766ff_row12_col20, #T_766ff_row23_col3, #T_766ff_row26_col1, #T_766ff_row26_col12 {
#   background-color: #e9e5f1;
#   color: #000000;
# }
# #T_766ff_row0_col15, #T_766ff_row2_col13, #T_766ff_row3_col4, #T_766ff_row7_col13, #T_766ff_row7_col17, #T_766ff_row11_col9, #T_766ff_row11_col13, #T_766ff_row12_col8, #T_766ff_row12_col14, #T_766ff_row14_col18, #T_766ff_row15_col20, #T_766ff_row17_col22, #T_766ff_row22_col4, #T_766ff_row22_col7, #T_766ff_row25_col6, #T_766ff_row26_col2 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_766ff_row0_col16, #T_766ff_row1_col9, #T_766ff_row1_col15, #T_766ff_row1_col16, #T_766ff_row6_col12, #T_766ff_row9_col7, #T_766ff_row12_col5, #T_766ff_row12_col23, #T_766ff_row13_col26, #T_766ff_row15_col2, #T_766ff_row16_col6, #T_766ff_row16_col12, #T_766ff_row17_col11, #T_766ff_row18_col7, #T_766ff_row18_col13, #T_766ff_row19_col15, #T_766ff_row20_col3, #T_766ff_row25_col5, #T_766ff_row25_col20, #T_766ff_row25_col21, #T_766ff_row26_col10, #T_766ff_row26_col15 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_766ff_row0_col17, #T_766ff_row0_col21, #T_766ff_row0_col23, #T_766ff_row4_col20, #T_766ff_row6_col8, #T_766ff_row8_col26, #T_766ff_row9_col2, #T_766ff_row14_col4, #T_766ff_row18_col8, #T_766ff_row20_col9, #T_766ff_row20_col26, #T_766ff_row23_col4, #T_766ff_row23_col21, #T_766ff_row25_col10, #T_766ff_row26_col16 {
#   background-color: #f4eef6;
#   color: #000000;
# }
# #T_766ff_row0_col18, #T_766ff_row1_col17, #T_766ff_row2_col9, #T_766ff_row4_col17, #T_766ff_row6_col13, #T_766ff_row12_col16, #T_766ff_row12_col26, #T_766ff_row15_col26, #T_766ff_row19_col6, #T_766ff_row20_col5, #T_766ff_row21_col16, #T_766ff_row24_col15, #T_766ff_row26_col6 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_766ff_row0_col20, #T_766ff_row1_col14, #T_766ff_row2_col7, #T_766ff_row3_col26, #T_766ff_row4_col24, #T_766ff_row8_col3, #T_766ff_row13_col16, #T_766ff_row14_col5, #T_766ff_row14_col16 {
#   background-color: #f3edf5;
#   color: #000000;
# }
# #T_766ff_row0_col22, #T_766ff_row0_col26, #T_766ff_row1_col18, #T_766ff_row2_col14, #T_766ff_row2_col17, #T_766ff_row3_col8, #T_766ff_row3_col25, #T_766ff_row4_col16, #T_766ff_row7_col12, #T_766ff_row9_col5, #T_766ff_row12_col17, #T_766ff_row13_col18, #T_766ff_row15_col17, #T_766ff_row15_col23, #T_766ff_row16_col25, #T_766ff_row16_col26, #T_766ff_row17_col13, #T_766ff_row18_col5, #T_766ff_row18_col11, #T_766ff_row20_col7, #T_766ff_row21_col2, #T_766ff_row22_col12, #T_766ff_row25_col2, #T_766ff_row25_col8, #T_766ff_row25_col19, #T_766ff_row26_col21, #T_766ff_row26_col22, #T_766ff_row26_col24 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_766ff_row0_col25, #T_766ff_row2_col3, #T_766ff_row3_col2, #T_766ff_row5_col16, #T_766ff_row7_col23, #T_766ff_row13_col22, #T_766ff_row16_col8, #T_766ff_row17_col9, #T_766ff_row21_col1, #T_766ff_row23_col6 {
#   background-color: #f6eff7;
#   color: #000000;
# }
# #T_766ff_row1_col0, #T_766ff_row6_col0 {
#   background-color: #045a8d;
#   color: #f1f1f1;
# }
# #T_766ff_row1_col2 {
#   background-color: #358fc0;
#   color: #f1f1f1;
# }
# #T_766ff_row1_col3, #T_766ff_row9_col11, #T_766ff_row14_col25, #T_766ff_row15_col14 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_766ff_row1_col4, #T_766ff_row12_col3, #T_766ff_row14_col7, #T_766ff_row15_col9 {

# %% [markdown]
# To interpret this dataframe, each cell represents the percentage of the row genre that also belongs to the colum genre.
#
# For example, the left column represents the percentage of each genre that also has the Fiction tag. The top row represents the percentage of Fiction-tagged books that also have each other genre.
#
# So, looking just at the 4 boxes in the upper-lefthand corner, 100% of Fiction is Fiction and 100% of Mystery is Mystery (of course), but also, 87% of Mystery is Fiction, and 45% of Fiction is Mystery. (This surprisingly large number is likely a consequence of the preponderance of Hardy Boys and Nancy Drew novels in the dataset).
#
# The darker colors near the left and on the top make sense, since the genres is sorted in order of frequency.
#
# ### Analysis
#
# Nearly everything is highly correlated with Fiction, except Nonfiction, History, and Biography, none of which ever coexist in the same book. This is promising for the accuracy of our data! But it also means that a classification for Fiction is likely redundant.
#
# 98% of Magic books fall under Fantasy, and Magic will likely be dropped. .
#
# 75% of Science Fiction Fantasy is Fantasy, and 70% of Science Fiction Fantasy is Science Fiction. So we can likely break up Science Fiction Fantasy into its component parts.

# %% [markdown]
# Now that we have some insight into features to drop, let's try actually dropping some. Let's say that we end up keeping exactly the features with more than 1000 books.

# %%
def filter_genres(genres, keep):
    filtered = [genre for genre in genres if genre in keep]
    return filtered

# %%
# Create an array of the top genres
keep_genres = top_genres['index'].values

# %%
# Create a new column on our dataframe with only the top genres
df['filtered genres'] = df['genre'].apply(lambda x: filter_genres(x, keep_genres))

# %%
df.head()
# Out:
#                                      title              author  total words
# 0                       The Vanished Birds       Simon Jimenez     124205.0  \
# 1                       The Price of Honor  Jonathan P. Brazee      77253.0
# 2  The Case of the Baker Street Irregulars     Anthony Boucher      80557.0
# 3                                  Wildoak    C. C. Harrington      55602.0
# 4                              The Holiday         T. M. Logan     101767.0
#
#    vividness  passive voice  all adverbs  ly-adverbs  non-ly-adverbs
# 0      55.18           6.37         1.95        0.36            1.58  \
# 1      35.35           8.71         2.63        0.71            1.92
# 2      32.33           8.41         3.72        1.64            2.08
# 3      74.34           6.92         3.04        1.16            1.87
# 4      50.30           8.02         3.06        1.12            1.93
#
#                                                genre    year  num genres
# 0  [Science Fiction, Fiction, Fantasy, Queer, LGB...  2020.0           7  \
# 1                                  [Science Fiction]  2017.0           1
# 2  [Mystery, Fiction, Crime, Humor, Classics, 20t...  1940.0           7
# 3  [Middle Grade, Historical Fiction, Fiction, An...  2022.0           7
# 4  [Thriller, Mystery, Fiction, Mystery Thriller,...  2019.0           7
#
#                                      filtered genres
# 0   [Science Fiction, Fiction, Fantasy, LGBT, Adult]
# 1                                  [Science Fiction]
# 2                [Mystery, Fiction, Crime, Classics]
# 3         [Historical Fiction, Fiction, Young Adult]
# 4  [Thriller, Mystery, Fiction, Mystery Thriller,...

# %%
# Create a new column with the number of genres from the allowed list in each book
df['num filtered genres'] = df['filtered genres'].apply(lambda x: len(x))

# %%
df.head()
# Out:
#                                      title              author  total words
# 0                       The Vanished Birds       Simon Jimenez     124205.0  \
# 1                       The Price of Honor  Jonathan P. Brazee      77253.0
# 2  The Case of the Baker Street Irregulars     Anthony Boucher      80557.0
# 3                                  Wildoak    C. C. Harrington      55602.0
# 4                              The Holiday         T. M. Logan     101767.0
#
#    vividness  passive voice  all adverbs  ly-adverbs  non-ly-adverbs
# 0      55.18           6.37         1.95        0.36            1.58  \
# 1      35.35           8.71         2.63        0.71            1.92
# 2      32.33           8.41         3.72        1.64            2.08
# 3      74.34           6.92         3.04        1.16            1.87
# 4      50.30           8.02         3.06        1.12            1.93
#
#                                                genre    year  num genres
# 0  [Science Fiction, Fiction, Fantasy, Queer, LGB...  2020.0           7  \
# 1                                  [Science Fiction]  2017.0           1
# 2  [Mystery, Fiction, Crime, Humor, Classics, 20t...  1940.0           7
# 3  [Middle Grade, Historical Fiction, Fiction, An...  2022.0           7
# 4  [Thriller, Mystery, Fiction, Mystery Thriller,...  2019.0           7
#
#                                      filtered genres  num filtered genres
# 0   [Science Fiction, Fiction, Fantasy, LGBT, Adult]                    5
# 1                                  [Science Fiction]                    1
# 2                [Mystery, Fiction, Crime, Classics]                    4
# 3         [Historical Fiction, Fiction, Young Adult]                    3
# 4  [Thriller, Mystery, Fiction, Mystery Thriller,...                    7

# %% [markdown]
# For reference, let's look at the description of the original genres list.

# %%
df['num genres'].describe()
# Out:
# count    22022.000000
# mean         5.975752
# std          1.884849
# min          1.000000
# 25%          6.000000
# 50%          7.000000
# 75%          7.000000
# max          7.000000
# Name: num genres, dtype: float64

# %% [markdown]
# Some books had only 1 genre, but 75% of the books had at least 6, and at least half had the maximum number I scraped from goodreads--7.
#
# Now let's see what happens after I remove every genre except the top ones.

# %%
df['num filtered genres'].describe()
# Out:
# count    22022.000000
# mean         3.967033
# std          1.792948
# min          0.000000
# 25%          3.000000
# 50%          4.000000
# 75%          5.000000
# max          7.000000
# Name: num filtered genres, dtype: float64

# %% [markdown]
# Now are mean has gone from around 6 to around 4, and the median has decreased all the way from 7 to 4. However, most books still have genres left.
#
# Let's see which books have lost all of their genres. I'll use a sample of the first and last 5 of those books.

# %%
lost_genres = df[df['num filtered genres'] == 0]
print(f"{len(lost_genres)} books no longer have any genres left. Here are some of them:")
pd.concat([lost_genres.head(),lost_genres.tail()])
# Out:
# 218 books no longer have any genres left. Here are some of them:
#                             title                              author
# 353              Startup Mixology                        Frank Gruber  \
# 492                Turbulent Wake                    Paul E. Hardisty
# 773    From Shy Guy To Ladies Man                          Chris Bale
# 1111               One Step Ahead                       Audrey Walker
# 1124                Dawn of Chaos  Daniel Willcocks & Michael Anderle
# 21729              The Outer Dark                     Zachary Rawlins
# 21772                   Endurance                       Brunoo Miller
# 21825        Emperor of the Earth                      Czeslaw Milosz
# 21833                   Blue Moon                       Jessica Saren
# 22129  How To Have Kick-Ass Ideas                 Chris Baréz-Brown
#
#        total words  vividness  passive voice  all adverbs  ly-adverbs
# 353        61170.0      19.85           7.47         2.81        1.00  \
# 492        84687.0      64.52           6.67         2.44        0.52
# 773        23616.0      28.81           7.85         4.16        1.89
# 1111       19968.0      28.98          10.51         3.49        0.93
# 1124       74595.0      51.85           7.20         2.93        1.02
# 21729     203197.0      48.58           6.94         3.56        1.72
# 21772      42029.0      43.12           8.19         2.82        1.00
# 21825      87103.0      21.72           6.22         2.94        1.13
# 21833      24065.0      50.20           6.61         3.44        1.73
# 22129      28957.0      26.86           8.99         4.20        1.14
#
#        non-ly-adverbs                                     genre    year
# 353              1.81  [Business, Entrepreneurship, Technology]  2014.0  \
# 492              1.93                                  [Canada]  2019.0
# 773              2.27                               [Self Help]  2016.0
# 1111             2.56                  [Psychological Thriller]  2021.0
# 1124             1.92                                 [Zombies]  2018.0
# 21729            1.84                           [Urban Fantasy]  2017.0
# 21772            1.82                                [Dystopia]  2019.0
# 21825            1.81       [Poetry, Poland, Criticism, Essays]  1977.0
# 21833            1.72                           [Reverse Harem]  2018.0
# 22129            3.06                                [Business]  2008.0
#
#        num genres filtered genres  num filtered genres
# 353             3              []                    0
# 492             1              []                    0
# 773             1              []                    0
# 1111            1              []                    0
# 1124            1              []                    0
# 21729           1              []                    0
# 21772           1              []                    0
# 21825           4              []                    0
# 21833           1              []                    0
# 22129           1              []                    0

# %%
lost_genres['num genres'].describe()
# Out:
# count    218.000000
# mean       1.458716
# std        0.916134
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        2.000000
# max        7.000000
# Name: num genres, dtype: float64

# %% [markdown]
# Most of the books that have lost all their genres had only 1 genre tag originally, and it did not happen to be a popular one. But at least some unlucky books had 7 genres, and none of them were winners.

# %%
lost_genres[lost_genres['num genres'] == 7]
# Out:
#              title       author  total words  vividness  passive voice
# 20233  Coming Home  Laurèn Lee      60114.0      57.65            6.2  \
#
#        all adverbs  ly-adverbs  non-ly-adverbs
# 20233         2.87        0.98            1.89  \
#
#                                                    genre    year  num genres
# 20233  [Comics, Graphic Novels, Marvel, Spider Man, C...  2001.0           7  \
#
#       filtered genres  num filtered genres
# 20233              []                    0

# %%
df.iloc[20233]['genre']
# Out:
# ['Comics',
#  'Graphic Novels',
#  'Marvel',
#  'Spider Man',
#  'Comic Book',
#  'Superheroes',
#  'Graphic Novels Comics']

# %% [markdown]
# Looks like there was just one book this unlucky--a Spider-Man comic.

# %% [markdown]
# Next, let's try splitting up the combination genres--Science Fiction Fantasy into Science Fiction and Fantasy, and Mystery Thriller into Mystery and Thriller.

# %%
def split_genres(genres):
    
    # So we don't change the original list
    split = genres.copy()
    
    if "Science Fiction Fantasy" in genres: 
        split.remove("Science Fiction Fantasy")
        split.append("Science Fiction")
        split.append("Fantasy")
        
        # Remove duplicates
        split = list(set(split))
        
    if "Mystery Thriller" in genres:
        split.remove("Mystery Thriller")
        split.append("Mystery")
        split.append("Thriller")
        
        # Remove duplicates
        split = list(set(split))
        
    return split

# %%
df['split genres'] = df['filtered genres'].apply(split_genres)

# %%
df.head()
# Out:
#                                      title              author  total words
# 0                       The Vanished Birds       Simon Jimenez     124205.0  \
# 1                       The Price of Honor  Jonathan P. Brazee      77253.0
# 2  The Case of the Baker Street Irregulars     Anthony Boucher      80557.0
# 3                                  Wildoak    C. C. Harrington      55602.0
# 4                              The Holiday         T. M. Logan     101767.0
#
#    vividness  passive voice  all adverbs  ly-adverbs  non-ly-adverbs
# 0      55.18           6.37         1.95        0.36            1.58  \
# 1      35.35           8.71         2.63        0.71            1.92
# 2      32.33           8.41         3.72        1.64            2.08
# 3      74.34           6.92         3.04        1.16            1.87
# 4      50.30           8.02         3.06        1.12            1.93
#
#                                                genre    year  num genres
# 0  [Science Fiction, Fiction, Fantasy, Queer, LGB...  2020.0           7  \
# 1                                  [Science Fiction]  2017.0           1
# 2  [Mystery, Fiction, Crime, Humor, Classics, 20t...  1940.0           7
# 3  [Middle Grade, Historical Fiction, Fiction, An...  2022.0           7
# 4  [Thriller, Mystery, Fiction, Mystery Thriller,...  2019.0           7
#
#                                      filtered genres  num filtered genres
# 0   [Science Fiction, Fiction, Fantasy, LGBT, Adult]                    5  \
# 1                                  [Science Fiction]                    1
# 2                [Mystery, Fiction, Crime, Classics]                    4
# 3         [Historical Fiction, Fiction, Young Adult]                    3
# 4  [Thriller, Mystery, Fiction, Mystery Thriller,...                    7
#
#                                         split genres
# 0   [Science Fiction, Fiction, Fantasy, LGBT, Adult]
# 1                                  [Science Fiction]
# 2                [Mystery, Fiction, Crime, Classics]
# 3         [Historical Fiction, Fiction, Young Adult]
# 4  [Suspense, Fiction, Mystery, Audiobook, Crime,...

# %%
df['num split genres'] = df['split genres'].apply(lambda x: len(x))

# %%
df.head()
# Out:
#                                      title              author  total words
# 0                       The Vanished Birds       Simon Jimenez     124205.0  \
# 1                       The Price of Honor  Jonathan P. Brazee      77253.0
# 2  The Case of the Baker Street Irregulars     Anthony Boucher      80557.0
# 3                                  Wildoak    C. C. Harrington      55602.0
# 4                              The Holiday         T. M. Logan     101767.0
#
#    vividness  passive voice  all adverbs  ly-adverbs  non-ly-adverbs
# 0      55.18           6.37         1.95        0.36            1.58  \
# 1      35.35           8.71         2.63        0.71            1.92
# 2      32.33           8.41         3.72        1.64            2.08
# 3      74.34           6.92         3.04        1.16            1.87
# 4      50.30           8.02         3.06        1.12            1.93
#
#                                                genre    year  num genres
# 0  [Science Fiction, Fiction, Fantasy, Queer, LGB...  2020.0           7  \
# 1                                  [Science Fiction]  2017.0           1
# 2  [Mystery, Fiction, Crime, Humor, Classics, 20t...  1940.0           7
# 3  [Middle Grade, Historical Fiction, Fiction, An...  2022.0           7
# 4  [Thriller, Mystery, Fiction, Mystery Thriller,...  2019.0           7
#
#                                      filtered genres  num filtered genres
# 0   [Science Fiction, Fiction, Fantasy, LGBT, Adult]                    5  \
# 1                                  [Science Fiction]                    1
# 2                [Mystery, Fiction, Crime, Classics]                    4
# 3         [Historical Fiction, Fiction, Young Adult]                    3
# 4  [Thriller, Mystery, Fiction, Mystery Thriller,...                    7
#
#                                         split genres  num split genres
# 0   [Science Fiction, Fiction, Fantasy, LGBT, Adult]                 5
# 1                                  [Science Fiction]                 1
# 2                [Mystery, Fiction, Crime, Classics]                 4
# 3         [Historical Fiction, Fiction, Young Adult]                 3
# 4  [Suspense, Fiction, Mystery, Audiobook, Crime,...                 6

# %%
print(df.iloc[4]['genre'])
print(df.iloc[4]['filtered genres'])
print(df.iloc[4]['split genres'])
# Out:
# ['Thriller', 'Mystery', 'Fiction', 'Mystery Thriller', 'Crime', 'Audiobook', 'Suspense']
# ['Thriller', 'Mystery', 'Fiction', 'Mystery Thriller', 'Crime', 'Audiobook', 'Suspense']
# ['Suspense', 'Fiction', 'Mystery', 'Audiobook', 'Crime', 'Thriller']

# %%
df['num split genres'].describe()
# Out:
# count    22022.000000
# mean         3.797975
# std          1.635543
# min          0.000000
# 25%          3.000000
# 50%          4.000000
# 75%          5.000000
# max          8.000000
# Name: num split genres, dtype: float64

# %%
to_1D(df['split genres']).value_counts()
# Out:
# Fiction               15167
# Mystery                8000
# Thriller               6659
# Fantasy                5970
# Audiobook              5477
# Science Fiction        3830
# Crime                  3765
# Contemporary           3328
# Romance                3234
# Nonfiction             3106
# Suspense               2937
# Historical Fiction     2917
# Adult                  2679
# Young Adult            2543
# Historical             1997
# Horror                 1595
# Adventure              1343
# Paranormal             1301
# History                1212
# Literary Fiction       1200
# Magic                  1131
# Novels                 1104
# Biography              1077
# Classics               1058
# LGBT                   1009
# Name: count, dtype: int64
