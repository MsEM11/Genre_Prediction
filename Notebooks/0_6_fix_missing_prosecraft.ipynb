# %% [markdown]
# This Notebook is to try to fill in missing values, where possible.

# %%
import requests
import json
import csv
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import random
import os
import string
from time import sleep
from dotenv import load_dotenv
from tqdm import tqdm, tqdm_notebook
from ratelimit import limits, sleep_and_retry
load_dotenv();

# %%
tqdm.pandas()

# %%
books = pd.read_csv('book_data_clean.csv')

# %% [markdown]
# First, let's drop our duplicate rows.

# %%
len(books)
# Out:
# 24971

# %%
books = books.drop_duplicates()

# %%
len(books)
# Out:
# 24861

# %%
books.head()
# Out:
#                                      title              author  total words
# 0                       The Vanished Birds       Simon Jimenez     124205.0  \
# 1                       The Price of Honor  Jonathan P. Brazee      77253.0
# 2     The Mathematical Murder of Innocence      Michael Carter      37688.0
# 3  The Case of the Baker Street Irregulars     Anthony Boucher      80557.0
# 4                            Zombie Nation      Charlie Dalton      64396.0
#
#    vividness  passive voice  all adverbs  ly-adverbs  non-ly-adverbs
# 0      55.18           6.37         1.95        0.36            1.58  \
# 1      35.35           8.71         2.63        0.71            1.92
# 2      24.08           8.11         4.13        1.56            2.58
# 3      32.33           8.41         3.72        1.64            2.08
# 4      51.11           8.22         2.21        0.58            1.63
#
#                                                genre    year
# 0  ['Science Fiction', 'Fiction', 'Fantasy', 'Que...  2020.0
# 1                                ['Science Fiction']  2017.0
# 2                                                 []  2020.0
# 3  ['Mystery', 'Fiction', 'Crime', 'Humor', 'Clas...  1940.0
# 4                                                 []  2020.0

# %% [markdown]
# I've noticed that some books are missing Prosecraft data. Let's find why.

# %%
missing_prosecraft = books[books['vividness'].isna()].copy()

# %%
len(missing_prosecraft)
# Out:
# 410

# %%
missing_prosecraft.head()
# Out:
#                                 title                    author  total words
# 176                 Infinite Baseball                  Alva No'          NaN  \
# 233          The Little Buddhist Monk               César Aira          NaN
# 329  The Fire Engine That Disappeared  Maj Sjöwall & Per Wahlöö          NaN
# 388           How to Turn Into a Bird      María José Ferrada          NaN
# 588     The Silence of the White City        Eva García Sáenz          NaN
#
#      vividness  passive voice  all adverbs  ly-adverbs  non-ly-adverbs
# 176        NaN            NaN          NaN         NaN             NaN  \
# 233        NaN            NaN          NaN         NaN             NaN
# 329        NaN            NaN          NaN         NaN             NaN
# 388        NaN            NaN          NaN         NaN             NaN
# 588        NaN            NaN          NaN         NaN             NaN
#
#                                                  genre    year
# 176  ['Baseball', 'Sports', 'Nonfiction', 'Philosop...  2019.0
# 233  ['Fiction', 'Latin American', 'Contemporary', ...  2017.0
# 329  ['Mystery', 'Crime', 'Fiction', 'Scandinavian ...  1969.0
# 388  ['Fiction', 'Contemporary', 'Coming Of Age', '...  2022.0
# 588  ['Thriller', 'Mystery', 'Crime', 'Fiction', 'S...  2016.0

# %% [markdown]
# What these seem to have in common is that they contain special characters. When I check the URL of the books on Prosecraft, the accents do not appear. That's likely where the error occurred. First, I find all the characters that appear in titles

# %%
alphanum = set('abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ1234567890 ')

# %%
print(set(missing_prosecraft.title.sum()+missing_prosecraft.author.sum()).difference(alphanum))
# Out:
# {'&', 'ï', '̈', '+', 'ä', '/', '?', '̧', ')', ',', 'ô', 'ë', '̂', 'ó', 'ō', '̃', 'Ø', 'é', '‘', 'Æ', '̊', '̀', '*', '[', 'ö', "'", 'à', 'í', ';', ':', 'ł', '%', 'â', 'ñ', '!', ']', 'ç', 'ø', 'ž', '̇', '̌', '’', '(', '.', '$', 'á', '°', 'ð', 'Ž', 'è', 'ü', '́', '#', '-', 'ū', '–'}

# %%
#Checked how each of the accented letter characters maps into a Prosecraft URL
replacements = {'à':'a','é':'e','â':'a','ç':'c','ñ':'n','Ž':'Z',
                'ž':'z','è':'e','ö':'o','á':'a','ó':'o','ū':'u',
                'í':'i','ô':'o','Ø':'O','ł':'l','ä':'a','ï':'i',
                'ë':'e','ü':'u','ō':'o','ð':'d','ć':'c','É':'E',
                'Ż':'Z','ô':'o','ş':'s','ũ':'u','Š':'S','ř':'r',
                'č':'c','ĩ':'i', 'š':'s','Æ':'Ae'}

# %%
missing_prosecraft['author_clean'] = missing_prosecraft['author']

# %%
for before, after in replacements.items():
    missing_prosecraft.author_clean = missing_prosecraft.author_clean.str.replace(before,after)

# %%
pd.concat([missing_prosecraft[['author','author_clean']].head(),(missing_prosecraft[['author','author_clean']].tail())])
# Out:
#                              author                  author_clean
# 176                        Alva No'                      Alva No'
# 233                     César Aira                   César Aira
# 329        Maj Sjöwall & Per Wahlöö      Maj Sjowall & Per Wahloo
# 388            María José Ferrada          María José Ferrada
# 588              Eva García Sáenz            Eva García Sáenz
# 24739              Ragnar Jónasson              Ragnar Jónasson
# 24745  María Amparo Ruiz de Burton  María Amparo Ruiz de Burton
# 24783               M. L. Longworth               M. L. Longworth
# 24955                     Tor Fleck                     Tor Fleck
# 24970                 Joe Schrieber                 Joe Schrieber

# %% [markdown]
# Hmm... not all of the accents are gone. Let's investigate why!

# %%
print(set(missing_prosecraft.author_clean.sum()).difference(alphanum))
# Out:
# {'&', '̈', "'", 'ø', '(', '.', ')', ',', '̊', '́', '̃', '-', '̀', '’'}

# %%
missing_prosecraft.iloc[1].author.replace('é','e')
# Out:
# 'César Aira'

# %% [markdown]
# Strange! It's almost as if it's a different character entirely. So I tried copy/pasting the accented e directly from the previous line's output, and...

# %%
missing_prosecraft.iloc[1].author.replace('é','e')
# Out:
# 'Cesar Aira'

# %% [markdown]
# Well, here's your problem!

# %%
'é' == 'é'
# Out:
# False

# %% [markdown]
# Let's try running this again with the accented letters that haven't changed replaced with the correct versions, copied directly from the DataFrame

# %%
corrected_replacements = {'á':'a','é':'e','ó':'o','ë':'e','í':'i','ü':'u',
                          'ñ':'n','ú':'u','Á':'A','Ó':'O','è':'e','ö':'o',
                          'ä':'a','Ö':'O','ø':'o','ï':'i','ò':'o','Ü':'U',
                          'à':'a','å':'a','Å':'A'}

# %%
for before, after in corrected_replacements.items():
    missing_prosecraft.author_clean = missing_prosecraft.author_clean.str.replace(before,after)

# %%
pd.concat([missing_prosecraft[['author','author_clean']].head(),(missing_prosecraft[['author','author_clean']].tail())])
# Out:
#                              author                 author_clean
# 176                        Alva No'                     Alva No'
# 233                     César Aira                   Cesar Aira
# 329        Maj Sjöwall & Per Wahlöö     Maj Sjowall & Per Wahloo
# 388            María José Ferrada           Maria Jose Ferrada
# 588              Eva García Sáenz             Eva Garcia Saenz
# 24739              Ragnar Jónasson              Ragnar Jonasson
# 24745  María Amparo Ruiz de Burton  Maria Amparo Ruiz de Burton
# 24783               M. L. Longworth              M. L. Longworth
# 24955                     Tor Fleck                    Tor Fleck
# 24970                 Joe Schrieber                Joe Schrieber

# %% [markdown]
# Now let's run it for the titles!

# %%
missing_prosecraft['title_clean'] = missing_prosecraft['title']

# %%
replacements.update(corrected_replacements)

# %%
for before, after in (replacements).items():
    missing_prosecraft.title_clean = missing_prosecraft.title_clean.str.replace(before,after)

# %%
#A few replacements made specifically in Prosecraft URLs
more_replacements = {'*':'-','&':'and'}

# %%
for before, after in (more_replacements).items():
    missing_prosecraft.title_clean = missing_prosecraft.title_clean.str.replace(before,after)
    missing_prosecraft.author_clean = missing_prosecraft.author_clean.str.replace(before,after)

# %%
pd.concat([missing_prosecraft[['title','title_clean']].head(),(missing_prosecraft[['title','title_clean']].tail())])
# Out:
#                                            title
# 176                            Infinite Baseball  \
# 233                     The Little Buddhist Monk
# 329             The Fire Engine That Disappeared
# 388                      How to Turn Into a Bird
# 588                The Silence of the White City
# 24739                                   The Mist
# 24745                   The Squatter and the Don
# 24783                            A Noël Killing
# 24955                                 Agency ‘O’
# 24970  Star Wars - The Mandalorian: Junior Novel
#
#                                      title_clean
# 176                            Infinite Baseball
# 233                     The Little Buddhist Monk
# 329             The Fire Engine That Disappeared
# 388                      How to Turn Into a Bird
# 588                The Silence of the White City
# 24739                                   The Mist
# 24745                   The Squatter and the Don
# 24783                             A Noel Killing
# 24955                                 Agency ‘O’
# 24970  Star Wars - The Mandalorian: Junior Novel

# %% [markdown]
# We still have a number of special characters left that are probably giving us trouble.

# %%
specials = set(missing_prosecraft.title_clean.sum()+missing_prosecraft.author_clean.sum()).difference(alphanum)
print(specials)
# Out:
# {'+', '/', '?', ')', ',', '‘', '[', "'", ';', ':', '%', '!', ']', '’', '(', '.', '$', '°', '#', '-', '–'}

# %%
special_df = pd.DataFrame()

# %%
#Creates a dataframe with only titles/authors whose cleaned version has special characters
for special in specials:
    special_df = pd.concat([special_df,missing_prosecraft[(missing_prosecraft['title_clean'].str.contains('\\'+special)) | 
                             (missing_prosecraft['author_clean'].str.contains('\\'+special))]])

# %%
print(len(special_df))
pd.concat([special_df.head(),special_df.tail()])
# Out:
# 398
#                                                    title
# 3402   Queer Intentions: A (Personal) journey through...  \
# 8834                                               X + Y
# 17712  1000+ Little Habits of Happy Successful Relati...
# 20841      I Travel By Night / Last Train From Perdition
# 2324                       Why? Explaining the Holocaust
# 23046                         How To Have Kick-Ass Ideas
# 23777             Star Trek - Voyager: To Lose the Earth
# 24666     Star Wars - Alphabet Squadron: Victory’s Price
# 24970          Star Wars - The Mandalorian: Junior Novel
# 7890                               The Mind–Body Problem
#
#                                author  total words  vividness  passive voice
# 3402                   Amelia Abraham          NaN        NaN            NaN  \
# 8834                    Eugenia Cheng          NaN        NaN            NaN
# 17712  Marc Chernoff & Angel Chernoff          NaN        NaN            NaN
# 20841                 Robert McCammon          NaN        NaN            NaN
# 2324                      Peter Hayes          NaN        NaN            NaN
# 23046             Chris Baréz-Brown           NaN        NaN            NaN
# 23777                   Kirsten Beyer          NaN        NaN            NaN
# 24666                 Alexander Freed          NaN        NaN            NaN
# 24970                   Joe Schrieber          NaN        NaN            NaN
# 7890                Jonathan Westphal          NaN        NaN            NaN
#
#        all adverbs  ly-adverbs  non-ly-adverbs
# 3402           NaN         NaN             NaN  \
# 8834           NaN         NaN             NaN
# 17712          NaN         NaN             NaN
# 20841          NaN         NaN             NaN
# 2324           NaN         NaN             NaN
# 23046          NaN         NaN             NaN
# 23777          NaN         NaN             NaN
# 24666          NaN         NaN             NaN
# 24970          NaN         NaN             NaN
# 7890           NaN         NaN             NaN
#
#                                                    genre    year
# 3402   ['Nonfiction', 'LGBT', 'Queer', 'Memoir', 'Aud...  2019.0  \
# 8834   ['Nonfiction', 'Feminism', 'Science', 'Gender'...  2020.0
# 17712  ['Nonfiction', 'Personal Development', 'Self H...  2021.0
# 20841                                         ['Horror']  2022.0
# 2324   ['History', 'Nonfiction', 'Holocaust', 'World ...  2017.0
# 23046                                                 []     NaN
# 23777  ['Star Trek', 'Science Fiction', 'Star Trek Vo...  2019.0
# 24666  ['Star Wars', 'Science Fiction', 'Fiction', 'F...  2021.0
# 24970                                                 []     NaN
# 7890   ['Philosophy', 'Nonfiction', 'Science', 'Psych...  2016.0
#
#                            author_clean
# 3402                     Amelia Abraham  \
# 8834                      Eugenia Cheng
# 17712  Marc Chernoff and Angel Chernoff
# 20841                   Robert McCammon
# 2324                        Peter Hayes
# 23046                Chris Barez-Brown
# 23777                     Kirsten Beyer
# 24666                   Alexander Freed
# 24970                     Joe Schrieber
# 7890                  Jonathan Westphal
#
#                                              title_clean
# 3402   Queer Intentions: A (Personal) journey through...
# 8834                                               X + Y
# 17712  1000+ Little Habits of Happy Successful Relati...
# 20841      I Travel By Night / Last Train From Perdition
# 2324                       Why? Explaining the Holocaust
# 23046                         How To Have Kick-Ass Ideas
# 23777             Star Trek - Voyager: To Lose the Earth
# 24666     Star Wars - Alphabet Squadron: Victory’s Price
# 24970          Star Wars - The Mandalorian: Junior Novel
# 7890                               The Mind–Body Problem

# %%
for special in specials:
    missing_prosecraft.title_clean = missing_prosecraft.title_clean.str.replace(special,'')
    missing_prosecraft.author_clean = missing_prosecraft.author_clean.str.replace(special,'')

# %%
missing_prosecraft.head()
# Out:
#                                 title                    author  total words
# 176                 Infinite Baseball                  Alva No'          NaN  \
# 233          The Little Buddhist Monk               César Aira          NaN
# 329  The Fire Engine That Disappeared  Maj Sjöwall & Per Wahlöö          NaN
# 388           How to Turn Into a Bird      María José Ferrada          NaN
# 588     The Silence of the White City        Eva García Sáenz          NaN
#
#      vividness  passive voice  all adverbs  ly-adverbs  non-ly-adverbs
# 176        NaN            NaN          NaN         NaN             NaN  \
# 233        NaN            NaN          NaN         NaN             NaN
# 329        NaN            NaN          NaN         NaN             NaN
# 388        NaN            NaN          NaN         NaN             NaN
# 588        NaN            NaN          NaN         NaN             NaN
#
#                                                  genre    year
# 176  ['Baseball', 'Sports', 'Nonfiction', 'Philosop...  2019.0  \
# 233  ['Fiction', 'Latin American', 'Contemporary', ...  2017.0
# 329  ['Mystery', 'Crime', 'Fiction', 'Scandinavian ...  1969.0
# 388  ['Fiction', 'Contemporary', 'Coming Of Age', '...  2022.0
# 588  ['Thriller', 'Mystery', 'Crime', 'Fiction', 'S...  2016.0
#
#                    author_clean                       title_clean
# 176                     Alva No                 Infinite Baseball
# 233                  Cesar Aira          The Little Buddhist Monk
# 329  Maj Sjowall and Per Wahloo  The Fire Engine That Disappeared
# 388          Maria Jose Ferrada           How to Turn Into a Bird
# 588            Eva Garcia Saenz     The Silence of the White City

# %%
#Find any non-alphanumerical special characters I've missed
specials = set(missing_prosecraft.title_clean.sum()+missing_prosecraft.author_clean.sum()).difference(alphanum)
print(specials)
# Out:
# set()

# %%
pd.concat([missing_prosecraft[['title_clean','author_clean']].head(),(missing_prosecraft[['title_clean','author_clean']].tail())])
# Out:
#                                    title_clean                 author_clean
# 176                          Infinite Baseball                      Alva No
# 233                   The Little Buddhist Monk                   Cesar Aira
# 329           The Fire Engine That Disappeared   Maj Sjowall and Per Wahloo
# 388                    How to Turn Into a Bird           Maria Jose Ferrada
# 588              The Silence of the White City             Eva Garcia Saenz
# 24739                                 The Mist              Ragnar Jonasson
# 24745                 The Squatter and the Don  Maria Amparo Ruiz de Burton
# 24783                           A Noel Killing                M L Longworth
# 24955                                 Agency O                    Tor Fleck
# 24970  Star Wars  The Mandalorian Junior Novel                Joe Schrieber

# %%
#recreate DataFrame of titles/authors involving special characters. 
#should be empty if I've done my job!
special_df = pd.DataFrame()

# %%
for special in specials:
    special_df = pd.concat([special_df,missing_prosecraft[(missing_prosecraft['title_clean'].str.contains('\\'+special)) | 
                             (missing_prosecraft['author_clean'].str.contains('\\'+special))]])

# %%
print(len(special_df))
special_df.head()
# Out:
# 0
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# Now we're ready to scrape the data from these 410 books!

# %%
@sleep_and_retry
@limits(calls=9, period=60)
def get_prosecraft(index):
    '''Given the cleaned title and author of a book, return the Prosecraft linguistic data'''
    
    sleep(random.uniform(0.5,1.5))
    
    #Copies the non-prosecraft columns of the original dataframe
    #row = missing_prosecraft[(missing_prosecraft['title_clean'] == title) & (missing_prosecraft['author_clean'] == author)]
    row = missing_prosecraft.loc[index]
    info = {'title': row['title'], 'author':row['author'], 
            'genre':row['genre'],'year':row['year']}
    
    #Formats the URL
    title = row['title_clean'].replace(' ','-').lower()
    author = row['author_clean'].replace(' ','-').lower()
    URL = f"http://prosecraft.io/library/{author}/{title}"
    
    
    #Fills out the missing elements of the original dataframe
    page = requests.get(URL)
    soup = BeautifulSoup(page.content, "html.parser")
    headings = soup.find_all("div", {"class": "book-info-metric-heading"})
    values = soup.find_all("div", {"class": "book-info-metric-value"})
    for heading, value in zip(headings, values):
        info[heading.text] = float(value.text.strip('%').replace(',',''))
        
    
    return pd.Series(info)

# %%
new_df = missing_prosecraft.progress_apply(lambda row: get_prosecraft(row.name), axis=1)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 410/410 [45:07<00:00,  6.60s/it]

# %%
#Make sure new dataframe has its columns in the right order
in_order = new_df[['title', 'author', 'total words', 'vividness', 'passive voice',
       'all adverbs', 'ly-adverbs', 'non-ly-adverbs', 'genre', 'year']]

# %%
#Let's put the new data onto the old, with the ones still missing prosecraft data dropped
merged = pd.concat([books,in_order]).dropna(subset=['vividness'])

# %% [markdown]
# A few cells to double check that the merge was successful.

# %%
#Length of original dataframe
len(books)
# Out:
# 24861

# %%
#Missing prosecraft data in original dataframe
sum(books['vividness'].isna())
# Out:
# 410

# %%
#Amount of missing prosecraft data we have not fixed
sum(in_order['vividness'].isna())
# Out:
# 85

# %%
#Length of the new dataframe
len(merged)
# Out:
# 24776

# %%
#Number of missing prosecraft values in the new dataframe
sum(merged['vividness'].isna())
# Out:
# 0

# %%
#Ideally, the merged dataframe should be shorter than the books dataframe
#by exactly as many books as we couldn't fix--in other words, 85. 
len(books) - len(merged)
# Out:
# 85

# %%
#Since all the fixed data is added onto the end, we should see some of it here.
merged.tail()
# Out:
#                           title
# 24667             Other Terrors  \
# 24739                  The Mist
# 24745  The Squatter and the Don
# 24783           A Noël Killing
# 24955                Agency ‘O’
#
#                                                   author  total words
# 24667  Various Authors (ed, Vince A. Liaguno & Rena M...     102917.0  \
# 24739                                   Ragnar Jónasson      63861.0
# 24745                       María Amparo Ruiz de Burton     136680.0
# 24783                                    M. L. Longworth      71960.0
# 24955                                          Tor Fleck      76068.0
#
#        vividness  passive voice  all adverbs  ly-adverbs  non-ly-adverbs
# 24667      65.86           6.74         2.36        0.67            1.68  \
# 24739      36.15          10.30         3.79        1.38            2.41
# 24745      30.19           8.71         3.83        1.09            2.74
# 24783      52.44           7.31         2.75        0.90            1.86
# 24955      55.25           6.79         2.65        1.05            1.61
#
#                                                    genre    year
# 24667  ['Horror', 'Short Stories', 'Anthologies', 'Fi...  2022.0
# 24739  ['Horror', 'Fiction', 'Thriller', 'Fantasy', '...  1980.0
# 24745  ['Fiction', 'Classics', 'School', '19th Centur...  1885.0
# 24783                                                 []     NaN
# 24955                                                 []     NaN

# %%
#As this csv was made successfully, I'm commenting it out when I rerun. 
#merged.to_csv('no_null_prosecraft.csv')

# %%
in_order[in_order['vividness'].isna()].head()
# Out:
#                                                 title
# 176                                 Infinite Baseball  \
# 892                                          ADHD 2.0
# 1491                               Walk Through Walls
# 1585                                         D.O.D.O.
# 1729                                           Zipped
# ...                                               ...
# 23987                             The Thirteenth Tale
# 24231                                            13.8
# 24386                                    (R)Evolution
# 24666  Star Wars - Alphabet Squadron: Victory’s Price
# 24970       Star Wars - The Mandalorian: Junior Novel
#
#                                     author  total words  vividness
# 176                               Alva No'          NaN        NaN  \
# 892    Edward M. Hallowell & John J. Ratey          NaN        NaN
# 1491                     Marina Abramović          NaN        NaN
# 1585      Neal Stephenson & Nicole Galland          NaN        NaN
# 1729            Laura McNeal & Tom McNeal           NaN        NaN
# ...                                    ...          ...        ...
# 23987                   Diane Setterfield           NaN        NaN
# 24231                         John Gribbin          NaN        NaN
# 24386                       M. E. Purfield          NaN        NaN
# 24666                      Alexander Freed          NaN        NaN
# 24970                        Joe Schrieber          NaN        NaN
#
#        passive voice  all adverbs  ly-adverbs  non-ly-adverbs
# 176              NaN          NaN         NaN             NaN  \
# 892              NaN          NaN         NaN             NaN
# 1491             NaN          NaN         NaN             NaN
# 1585             NaN          NaN         NaN             NaN
# 1729             NaN          NaN         NaN             NaN
# ...              ...          ...         ...             ...
# 23987            NaN          NaN         NaN             NaN
# 24231            NaN          NaN         NaN             NaN
# 24386            NaN          NaN         NaN             NaN
# 24666            NaN          NaN         NaN             NaN
# 24970            NaN          NaN         NaN             NaN
#
#                                                    genre    year
# 176    ['Baseball', 'Sports', 'Nonfiction', 'Philosop...  2019.0
# 892    ['Adhd', 'Nonfiction', 'Psychology', 'Self Hel...  2021.0
# 1491   ['Art', 'Nonfiction', 'Memoir', 'Biography', '...  2016.0
# 1585   ['Science Fiction', 'Fantasy', 'Fiction', 'Tim...  2017.0
# 1729   ['Young Adult', 'Fiction', 'Realistic Fiction'...  2003.0
# ...                                                  ...     ...
# 23987  ['Fiction', 'Mystery', 'Historical Fiction', '...  2006.0
# 24231                                                 []     NaN
# 24386                                                 []     NaN
# 24666  ['Star Wars', 'Science Fiction', 'Fiction', 'F...  2021.0
# 24970                                                 []     NaN
#
# [85 rows x 10 columns]

# %%
missing_prosecraft = missing_prosecraft[in_order['vividness'].isna()]

# %%
missing_prosecraft.head()
# Out:
#                    title                               author  total words
# 176    Infinite Baseball                             Alva No'          NaN  \
# 892             ADHD 2.0  Edward M. Hallowell & John J. Ratey          NaN
# 1491  Walk Through Walls                    Marina Abramović          NaN
# 1585            D.O.D.O.     Neal Stephenson & Nicole Galland          NaN
# 1729              Zipped           Laura McNeal & Tom McNeal           NaN
#
#       vividness  passive voice  all adverbs  ly-adverbs  non-ly-adverbs
# 176         NaN            NaN          NaN         NaN             NaN  \
# 892         NaN            NaN          NaN         NaN             NaN
# 1491        NaN            NaN          NaN         NaN             NaN
# 1585        NaN            NaN          NaN         NaN             NaN
# 1729        NaN            NaN          NaN         NaN             NaN
#
#                                                   genre    year
# 176   ['Baseball', 'Sports', 'Nonfiction', 'Philosop...  2019.0  \
# 892   ['Adhd', 'Nonfiction', 'Psychology', 'Self Hel...  2021.0
# 1491  ['Art', 'Nonfiction', 'Memoir', 'Biography', '...  2016.0
# 1585  ['Science Fiction', 'Fantasy', 'Fiction', 'Tim...  2017.0
# 1729  ['Young Adult', 'Fiction', 'Realistic Fiction'...  2003.0
#
#                              author_clean         title_clean
# 176                               Alva No   Infinite Baseball
# 892   Edward M Hallowell and John J Ratey             ADHD 20
# 1491                     Marina Abramovic  Walk Through Walls
# 1585   Neal Stephenson and Nicole Galland                DODO
# 1729         Laura McNeal and Tom McNeal               Zipped

# %%
#This one's a formatting error I caused myself. May as well fix it. 
missing_prosecraft.loc[176, 'author'] = 'Alva Noë'
missing_prosecraft.loc[176, 'author_clean'] = 'Alva Noe'

# %%
missing_prosecraft.head()
# Out:
#                    title                               author  total words
# 176    Infinite Baseball                             Alva Noë          NaN  \
# 892             ADHD 2.0  Edward M. Hallowell & John J. Ratey          NaN
# 1491  Walk Through Walls                    Marina Abramović          NaN
# 1585            D.O.D.O.     Neal Stephenson & Nicole Galland          NaN
# 1729              Zipped           Laura McNeal & Tom McNeal           NaN
#
#       vividness  passive voice  all adverbs  ly-adverbs  non-ly-adverbs
# 176         NaN            NaN          NaN         NaN             NaN  \
# 892         NaN            NaN          NaN         NaN             NaN
# 1491        NaN            NaN          NaN         NaN             NaN
# 1585        NaN            NaN          NaN         NaN             NaN
# 1729        NaN            NaN          NaN         NaN             NaN
#
#                                                   genre    year
# 176   ['Baseball', 'Sports', 'Nonfiction', 'Philosop...  2019.0  \
# 892   ['Adhd', 'Nonfiction', 'Psychology', 'Self Hel...  2021.0
# 1491  ['Art', 'Nonfiction', 'Memoir', 'Biography', '...  2016.0
# 1585  ['Science Fiction', 'Fantasy', 'Fiction', 'Tim...  2017.0
# 1729  ['Young Adult', 'Fiction', 'Realistic Fiction'...  2003.0
#
#                              author_clean         title_clean
# 176                              Alva Noe   Infinite Baseball
# 892   Edward M Hallowell and John J Ratey             ADHD 20
# 1491                     Marina Abramovic  Walk Through Walls
# 1585   Neal Stephenson and Nicole Galland                DODO
# 1729         Laura McNeal and Tom McNeal               Zipped

# %% [markdown]
# I checked some values and noticed that in titles like ADHD 2.0 and D.O.D.O, the period gets turned into a space, *not* dropped. Let's try fixing that.

# %%
missing_prosecraft[missing_prosecraft['title'].str.contains('\.')].head()
# Out:
#                                     title
# 892                              ADHD 2.0  \
# 1585                             D.O.D.O.
# 2578               Corruption in the O.R.
# 3390                             Life 3.0
# 4830                       Tough Luck L.A
# 7806                      Z.E.D.S. Rising
# 8468   The Love Songs of W. E. B. Du Bois
# 10899                            H.I.V.E.
# 15293               Seduce With Style 2.0
# 21909                        L.A. Weather
# 22911                          README.txt
# 23910                      Heir of G.O.D.
# 24231                                13.8
#
#                                     author  total words  vividness
# 892    Edward M. Hallowell & John J. Ratey          NaN        NaN  \
# 1585      Neal Stephenson & Nicole Galland          NaN        NaN
# 2578                          Barbara Ebel          NaN        NaN
# 3390                           Max Tegmark          NaN        NaN
# 4830                       Murray Sinclair          NaN        NaN
# 7806                         Bradley Botts          NaN        NaN
# 8468              Honorée Fanonne Jeffers           NaN        NaN
# 10899                          Mark Walden          NaN        NaN
# 15293                            Vince Lin          NaN        NaN
# 21909                María Amparo Escandón          NaN        NaN
# 22911                      Chelsea Manning          NaN        NaN
# 23910                          Harper Maze          NaN        NaN
# 24231                         John Gribbin          NaN        NaN
#
#        passive voice  all adverbs  ly-adverbs  non-ly-adverbs
# 892              NaN          NaN         NaN             NaN  \
# 1585             NaN          NaN         NaN             NaN
# 2578             NaN          NaN         NaN             NaN
# 3390             NaN          NaN         NaN             NaN
# 4830             NaN          NaN         NaN             NaN
# 7806             NaN          NaN         NaN             NaN
# 8468             NaN          NaN         NaN             NaN
# 10899            NaN          NaN         NaN             NaN
# 15293            NaN          NaN         NaN             NaN
# 21909            NaN          NaN         NaN             NaN
# 22911            NaN          NaN         NaN             NaN
# 23910            NaN          NaN         NaN             NaN
# 24231            NaN          NaN         NaN             NaN
#
#                                                    genre    year
# 892    ['Adhd', 'Nonfiction', 'Psychology', 'Self Hel...  2021.0  \
# 1585   ['Science Fiction', 'Fantasy', 'Fiction', 'Tim...  2017.0
# 2578                                                  []  2019.0
# 3390   ['Science', 'Nonfiction', 'Artificial Intellig...  2017.0
# 4830                                           ['Crime']  1981.0
# 7806                                                  []  2016.0
# 8468                                                  []     NaN
# 10899  ['Young Adult', 'Science Fiction', 'Adventure'...  2006.0
# 15293                                                 []  2012.0
# 21909  ['Fiction', 'Audiobook', 'Contemporary', 'Adul...  2021.0
# 22911  ['Nonfiction', 'Memoir', 'Politics', 'Queer', ...  2022.0
# 23910                    ['Dystopia', 'Science Fiction']  2020.0
# 24231                                                 []     NaN
#
#                               author_clean                      title_clean
# 892    Edward M Hallowell and John J Ratey                          ADHD 20
# 1585    Neal Stephenson and Nicole Galland                             DODO
# 2578                          Barbara Ebel             Corruption in the OR
# 3390                           Max Tegmark                          Life 30
# 4830                       Murray Sinclair                    Tough Luck LA
# 7806                         Bradley Botts                      ZEDS Rising
# 8468              Honoree Fanonne Jeffers   The Love Songs of W E B Du Bois
# 10899                          Mark Walden                             HIVE
# 15293                            Vince Lin             Seduce With Style 20
# 21909                Maria Amparo Escandon                       LA Weather
# 22911                      Chelsea Manning                        READMEtxt
# 23910                          Harper Maze                      Heir of GOD
# 24231                         John Gribbin                              138

# %%
missing_prosecraft.loc[:,'title_clean'] = missing_prosecraft['title'].str.replace('.', ' ')\
                                        .str.replace(' - ', ' ').str.replace('-',' ')\
                                        .str.replace('(',' ').str.replace(')',' ').str.replace(',',' ').str.strip()

# %%
missing_prosecraft.loc[:,'author_clean'] = missing_prosecraft['author'].str.replace('.',' ').str.replace('-',' ')

# %%
missing_prosecraft.sample(5)
# Out:
#                                         title
# 20926                                    Mars  \
# 23777  Star Trek - Voyager: To Lose the Earth
# 9222                             In Veritas -
# 5545                   Stories: All-New Tales
# 4985      Star Trek - Discovery: Die Standing
#
#                                                   author  total words
# 20926                                        Asja Bakić          NaN  \
# 23777                                      Kirsten Beyer          NaN
# 9222                                       C. J. Lavigne          NaN
# 5545   Various Authors (ed, Neil Gaiman & Al Sarranto...          NaN
# 4985                                 John Jackson Miller          NaN
#
#        vividness  passive voice  all adverbs  ly-adverbs  non-ly-adverbs
# 20926        NaN            NaN          NaN         NaN             NaN  \
# 23777        NaN            NaN          NaN         NaN             NaN
# 9222         NaN            NaN          NaN         NaN             NaN
# 5545         NaN            NaN          NaN         NaN             NaN
# 4985         NaN            NaN          NaN         NaN             NaN
#
#                                                    genre    year
# 20926  ['Nonfiction', 'Self Help', 'Psychology', 'Rel...  1992.0  \
# 23777  ['Star Trek', 'Science Fiction', 'Star Trek Vo...  2019.0
# 9222                                                  []     NaN
# 5545   ['Short Stories', 'Fantasy', 'Fiction', 'Antho...  2010.0
# 4985   ['Star Trek', 'Science Fiction', 'Fiction', 'A...  2020.0
#
#                                             author_clean
# 20926                                        Asja Bakić  \
# 23777                                      Kirsten Beyer
# 9222                                       C  J  Lavigne
# 5545   Various Authors (ed, Neil Gaiman & Al Sarranto...
# 4985                                 John Jackson Miller
#
#                                 title_clean
# 20926                                  Mars
# 23777  Star Trek Voyager: To Lose the Earth
# 9222                             In Veritas
# 5545                 Stories: All New Tales
# 4985      Star Trek Discovery: Die Standing

# %% [markdown]
# This is progress, I think! Except now I've undone all my good work with the special characters I removed and replaced with letters before! Let's try looping through those again.

# %%
missing_prosecraft.loc[23046]['title_clean']
# Out:
# 'How To Have Kick Ass Ideas'

# %%
for before, after in replacements.items():
    missing_prosecraft.loc[:,'author_clean'] = missing_prosecraft['author_clean'].str.replace(before,after)
    missing_prosecraft.loc[:,'title_clean'] = missing_prosecraft['title_clean'].str.replace(before, after)

# %%
for before, after in (more_replacements).items():
    missing_prosecraft.loc[:,'title_clean'] = missing_prosecraft.title_clean.str.replace(before,after)
    missing_prosecraft.loc[:,'author_clean'] = missing_prosecraft.author_clean.str.replace(before,after)

# %%
missing_prosecraft.sample(5)
# Out:
#                             title                            author
# 5288          A New Idea of India  Harsh Madhusudan & Rajeev Mantri  \
# 19828              Erotic Fantasy                Hans-Jürgen Döpp
# 23910              Heir of G.O.D.                       Harper Maze
# 23046  How To Have Kick-Ass Ideas               Chris Baréz-Brown
# 1729                       Zipped        Laura McNeal & Tom McNeal
#
#        total words  vividness  passive voice  all adverbs  ly-adverbs
# 5288           NaN        NaN            NaN          NaN         NaN  \
# 19828          NaN        NaN            NaN          NaN         NaN
# 23910          NaN        NaN            NaN          NaN         NaN
# 23046          NaN        NaN            NaN          NaN         NaN
# 1729           NaN        NaN            NaN          NaN         NaN
#
#        non-ly-adverbs                                              genre
# 5288              NaN                                                 []  \
# 19828             NaN  ['Romance', 'Erotica', 'Fiction', 'Sexuality',...
# 23910             NaN                    ['Dystopia', 'Science Fiction']
# 23046             NaN                                                 []
# 1729              NaN  ['Young Adult', 'Fiction', 'Realistic Fiction'...
#
#          year                        author_clean                 title_clean
# 5288      NaN  Harsh Madhusudan and Rajeev Mantri         A New Idea of India
# 19828  2018.0                    Hans Jurgen Dopp              Erotic Fantasy
# 23910  2020.0                         Harper Maze               Heir of G O D
# 23046     NaN                  Chris Barez Brown   How To Have Kick Ass Ideas
# 1729   2003.0        Laura McNeal and Tom McNeal                       Zipped

# %% [markdown]
# Noticed a weird one! It turns out there's two copies of a book on the actual Prosecraft website, and one of them is a formatting error. Instead of "Bombshell", by Stuart Woods & Parnell Hall, we have "& Parnell Hall - Bombshell" by Stuart Woods! The corrected version is already safely on the main dataframe.

# %%
missing_prosecraft.loc[18545]
# Out:
# title             & Parnell Hall - Bombshell
# author                          Stuart Woods
# total words                              NaN
# vividness                                NaN
# passive voice                            NaN
# all adverbs                              NaN
# ly-adverbs                               NaN
# non-ly-adverbs                           NaN
# genre                                     []
# year                                     NaN
# author_clean                    Stuart Woods
# title_clean       and Parnell Hall Bombshell
# Name: 18545, dtype: object

# %%
books[books['title'] == 'Bombshell']
# Out:
#            title                       author  total words  vividness
# 10270  Bombshell                Sarah Maclean     102513.0      40.84  \
# 11547  Bombshell  Stuart Woods & Parnell Hall      57004.0      34.21
#
#        passive voice  all adverbs  ly-adverbs  non-ly-adverbs
# 10270            8.3         3.64        1.80            1.84  \
# 11547           10.2         2.41        0.72            1.69
#
#                                                    genre    year
# 10270  ['Romance', 'Historical Romance', 'Historical'...  2021.0
# 11547  ['Mystery', 'Fiction', 'Thriller', 'Crime', 'M...  2020.0

# %%
#Getting rid of the formatting error! 
missing_prosecraft = missing_prosecraft.drop(18545)

# %% [markdown]
# Time to take care of our special characters again!

# %%
specials = set(missing_prosecraft.title_clean.sum()+missing_prosecraft.author_clean.sum()).difference(alphanum)
specials
# Out:
# {'!', '$', '(', ')', '+', ',', '-', '/', ':', '–', '’'}

# %%
for special in specials:
    missing_prosecraft.loc[:, 'title_clean'] = missing_prosecraft.title_clean.str.replace(special,'')
    missing_prosecraft.loc[:, 'author_clean'] = missing_prosecraft.author_clean.str.replace(special,'')

# %%
missing_prosecraft.sample(5)
# Out:
#                                   title                 author  total words
# 4830                     Tough Luck L.A        Murray Sinclair          NaN  \
# 21275  Star Wars - Aftermath: Life Debt           Chuck Wendig          NaN
# 10899                          H.I.V.E.            Mark Walden          NaN
# 21909                      L.A. Weather  María Amparo Escandón          NaN
# 1491                 Walk Through Walls      Marina Abramović          NaN
#
#        vividness  passive voice  all adverbs  ly-adverbs  non-ly-adverbs
# 4830         NaN            NaN          NaN         NaN             NaN  \
# 21275        NaN            NaN          NaN         NaN             NaN
# 10899        NaN            NaN          NaN         NaN             NaN
# 21909        NaN            NaN          NaN         NaN             NaN
# 1491         NaN            NaN          NaN         NaN             NaN
#
#                                                    genre    year
# 4830                                           ['Crime']  1981.0  \
# 21275  ['Star Wars', 'Science Fiction', 'Fiction', 'F...  2016.0
# 10899  ['Young Adult', 'Science Fiction', 'Adventure'...  2006.0
# 21909  ['Fiction', 'Audiobook', 'Contemporary', 'Adul...  2021.0
# 1491   ['Art', 'Nonfiction', 'Memoir', 'Biography', '...  2016.0
#
#                 author_clean                    title_clean
# 4830         Murray Sinclair                 Tough Luck L A
# 21275           Chuck Wendig  Star Wars Aftermath Life Debt
# 10899            Mark Walden                        H I V E
# 21909  Maria Amparo Escandon                   L A  Weather
# 1491        Marina Abramovic             Walk Through Walls

# %% [markdown]
# Okay, we're ready to try running these through the function again!

# %%
new_df = missing_prosecraft.progress_apply(lambda row: get_prosecraft(row.name), axis=1)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 84/84 [09:02<00:00,  6.45s/it]

# %%
len(new_df[new_df['vividness'].notna()])
# Out:
# 53

# %% [markdown]
# Great! It looks like that's fixed 53 of the 85 missing values!

# %%
in_order = new_df[['title', 'author', 'total words', 'vividness', 'passive voice',
       'all adverbs', 'ly-adverbs', 'non-ly-adverbs', 'genre', 'year']]

# %%
len(merged)
# Out:
# 24776

# %%
len(pd.concat([merged,in_order]).dropna(subset=['vividness']))
# Out:
# 24829

# %%
merged = pd.concat([merged,in_order]).dropna(subset=['vividness'])

# %%
#merged.to_csv('no_null_prosecraft.csv')

# %%
missing_prosecraft = missing_prosecraft[in_order['vividness'].isna()]

# %%
missing_prosecraft.head()
# Out:
#                                                    title
# 892                                             ADHD 2.0  \
# 1491                                  Walk Through Walls
# 1729                                              Zipped
# 2886                             Morning  noon and night
# 3438              Star Wars - Galaxy’s Edge: Black Spire
# 3737                                    Creation Machine
# 3977   Goosebumps - Slappy World: Please Do Not Feed ...
# 4508                                          Magic Lies
# 5215                            The Khruellian Encounter
# 7506                             The Three Secret Cities
# 7806                                     Z.E.D.S. Rising
# 7890                               The Mind–Body Problem
# 8468                  The Love Songs of W. E. B. Du Bois
# 8834                                               X + Y
# 9222                                        In Veritas -
# 13479       Star Wars - The New Jedi Order: Vector Prime
# 13762                               Blessing in Disguise
# 14550                                         Belladonna
# 14708                              Blinded by the Lights
# 15171                                     Weep Not Child
# 17079         The Girl Who Could Move Sh*t With Her Mind
# 18860                                 The Stolen Sisters
# 20841      I Travel By Night / Last Train From Perdition
# 20926                                               Mars
# 21060                           I’m Sorry  Feel That Way
# 21909                                       L.A. Weather
# 22557                                   Minutes of Glory
# 23046                         How To Have Kick-Ass Ideas
# 23412                                   The Perfect Nine
# 23987                                The Thirteenth Tale
# 24386                                       (R)Evolution
#
#                                     author  total words  vividness
# 892    Edward M. Hallowell & John J. Ratey          NaN        NaN  \
# 1491                     Marina Abramović          NaN        NaN
# 1729            Laura McNeal & Tom McNeal           NaN        NaN
# 2886                        Sidney Sheldon          NaN        NaN
# 3438                     Delilah S. Dawson          NaN        NaN
# 3737                     Andrew Bannister           NaN        NaN
# 3977                           R. L. Stine          NaN        NaN
# 4508                         C.C. Sommerly          NaN        NaN
# 5215                        C. J.  Klinger          NaN        NaN
# 7506                       Matthew Reilly           NaN        NaN
# 7806                         Bradley Botts          NaN        NaN
# 7890                     Jonathan Westphal          NaN        NaN
# 8468              Honorée Fanonne Jeffers           NaN        NaN
# 8834                         Eugenia Cheng          NaN        NaN
# 9222                         C. J. Lavigne          NaN        NaN
# 13479                      R. A. Salvatore          NaN        NaN
# 13762                      Danielle Steel           NaN        NaN
# 14550                        Daša Drndić          NaN        NaN
# 14708                       Jakub Żulczyk          NaN        NaN
# 15171                  Ngũgĩ wa Thiong’o          NaN        NaN
# 17079                         Jackson Ford          NaN        NaN
# 18860                       Louise Jensen           NaN        NaN
# 20841                      Robert McCammon          NaN        NaN
# 20926                          Asja Bakić          NaN        NaN
# 21060                         Diana Joseph          NaN        NaN
# 21909                María Amparo Escandón          NaN        NaN
# 22557                  Ngũgĩ wa Thiong’o          NaN        NaN
# 23046                  Chris Baréz-Brown           NaN        NaN
# 23412                  Ngũgĩ wa Thiong’o          NaN        NaN
# 23987                   Diane Setterfield           NaN        NaN
# 24386                       M. E. Purfield          NaN        NaN
#
#        passive voice  all adverbs  ly-adverbs  non-ly-adverbs
# 892              NaN          NaN         NaN             NaN  \
# 1491             NaN          NaN         NaN             NaN
# 1729             NaN          NaN         NaN             NaN
# 2886             NaN          NaN         NaN             NaN
# 3438             NaN          NaN         NaN             NaN
# 3737             NaN          NaN         NaN             NaN
# 3977             NaN          NaN         NaN             NaN
# 4508             NaN          NaN         NaN             NaN
# 5215             NaN          NaN         NaN             NaN
# 7506             NaN          NaN         NaN             NaN
# 7806             NaN          NaN         NaN             NaN
# 7890             NaN          NaN         NaN             NaN
# 8468             NaN          NaN         NaN             NaN
# 8834             NaN          NaN         NaN             NaN
# 9222             NaN          NaN         NaN             NaN
# 13479            NaN          NaN         NaN             NaN
# 13762            NaN          NaN         NaN             NaN
# 14550            NaN          NaN         NaN             NaN
# 14708            NaN          NaN         NaN             NaN
# 15171            NaN          NaN         NaN             NaN
# 17079            NaN          NaN         NaN             NaN
# 18860            NaN          NaN         NaN             NaN
# 20841            NaN          NaN         NaN             NaN
# 20926            NaN          NaN         NaN             NaN
# 21060            NaN          NaN         NaN             NaN
# 21909            NaN          NaN         NaN             NaN
# 22557            NaN          NaN         NaN             NaN
# 23046            NaN          NaN         NaN             NaN
# 23412            NaN          NaN         NaN             NaN
# 23987            NaN          NaN         NaN             NaN
# 24386            NaN          NaN         NaN             NaN
#
#                                                    genre    year
# 892    ['Adhd', 'Nonfiction', 'Psychology', 'Self Hel...  2021.0  \
# 1491   ['Art', 'Nonfiction', 'Memoir', 'Biography', '...  2016.0
# 1729   ['Young Adult', 'Fiction', 'Realistic Fiction'...  2003.0
# 2886   ['Fiction', 'Thriller', 'Mystery', 'Suspense',...  1995.0
# 3438   ['Star Wars', 'Science Fiction', 'Fiction', 'A...  2019.0
# 3737   ['Science Fiction', 'Fiction', 'Space Opera', ...  2016.0
# 3977                                                  []     NaN
# 4508                                                  []  2020.0
# 5215                                                  []  2014.0
# 7506                                                  []     NaN
# 7806                                                  []  2016.0
# 7890   ['Philosophy', 'Nonfiction', 'Science', 'Psych...  2016.0
# 8468                                                  []     NaN
# 8834   ['Nonfiction', 'Feminism', 'Science', 'Gender'...  2020.0
# 9222                                                  []     NaN
# 13479                                                 []     NaN
# 13762                                                 []     NaN
# 14550  ['Fantasy', 'Romance', 'Young Adult', 'Mystery...  2022.0
# 14708  ['Polish Literature', 'Fiction', 'Thriller', '...  2014.0
# 15171                              ['Africa', 'Fiction']  2005.0
# 17079  ['Science Fiction', 'Fantasy', 'Mystery', 'Fic...  2019.0
# 18860  ['Thriller', 'Mystery', 'Fiction', 'Crime', 'S...  2020.0
# 20841                                         ['Horror']  2022.0
# 20926  ['Nonfiction', 'Self Help', 'Psychology', 'Rel...  1992.0
# 21060  ['Memoir', 'Nonfiction', 'Humor', 'Biography',...  2009.0
# 21909  ['Fiction', 'Audiobook', 'Contemporary', 'Adul...  2021.0
# 22557  ['Short Stories', 'Fiction', 'Africa', 'Kenya'...  2019.0
# 23046                                                 []     NaN
# 23412  ['Fiction', 'Poetry', 'Africa', 'Mythology', '...  2018.0
# 23987  ['Fiction', 'Mystery', 'Historical Fiction', '...  2006.0
# 24386                                                 []     NaN
#
#                                 author_clean
# 892    Edward M  Hallowell and John J  Ratey  \
# 1491                        Marina Abramovic
# 1729            Laura McNeal and Tom McNeal
# 2886                          Sidney Sheldon
# 3438                       Delilah S  Dawson
# 3737                       Andrew Bannister
# 3977                             R  L  Stine
# 4508                           C C  Sommerly
# 5215                          C  J   Klinger
# 7506                         Matthew Reilly
# 7806                           Bradley Botts
# 7890                       Jonathan Westphal
# 8468                Honoree Fanonne Jeffers
# 8834                           Eugenia Cheng
# 9222                           C  J  Lavigne
# 13479                        R  A  Salvatore
# 13762                        Danielle Steel
# 14550                            Dasa Drndic
# 14708                          Jakub Zulczyk
# 15171                       Ngugi wa Thiongo
# 17079                           Jackson Ford
# 18860                         Louise Jensen
# 20841                        Robert McCammon
# 20926                             Asja Bakic
# 21060                           Diana Joseph
# 21909                  Maria Amparo Escandon
# 22557                       Ngugi wa Thiongo
# 23046                     Chris Barez Brown
# 23412                       Ngugi wa Thiongo
# 23987                     Diane Setterfield
# 24386                         M  E  Purfield
#
#                                              title_clean
# 892                                             ADHD 2 0
# 1491                                  Walk Through Walls
# 1729                                              Zipped
# 2886                             Morning  noon and night
# 3438                  Star Wars Galaxys Edge Black Spire
# 3737                                    Creation Machine
# 3977   Goosebumps Slappy World Please Do Not Feed the...
# 4508                                          Magic Lies
# 5215                            The Khruellian Encounter
# 7506                             The Three Secret Cities
# 7806                                     Z E D S  Rising
# 7890                                The MindBody Problem
# 8468                  The Love Songs of W  E  B  Du Bois
# 8834                                                X  Y
# 9222                                          In Veritas
# 13479          Star Wars The New Jedi Order Vector Prime
# 13762                               Blessing in Disguise
# 14550                                         Belladonna
# 14708                              Blinded by the Lights
# 15171                                     Weep Not Child
# 17079          The Girl Who Could Move Sht With Her Mind
# 18860                                 The Stolen Sisters
# 20841       I Travel By Night  Last Train From Perdition
# 20926                                               Mars
# 21060                            Im Sorry  Feel That Way
# 21909                                       L A  Weather
# 22557                                   Minutes of Glory
# 23046                         How To Have Kick Ass Ideas
# 23412                                   The Perfect Nine
# 23987                                The Thirteenth Tale
# 24386                                        R Evolution

# %% [markdown]
# I'm later going to clear the ones where goodreads has no genre data, since genre is my target feature. Those will be the ones where the year exists but the genre list is empty. So let's not worry about fixing those ones!

# %%
missing_prosecraft[(missing_prosecraft['genre'] == '[]') & (missing_prosecraft['year'].notna())]
# Out:
#                          title          author  total words  vividness
# 4508                Magic Lies   C.C. Sommerly          NaN        NaN  \
# 5215  The Khruellian Encounter  C. J.  Klinger          NaN        NaN
# 7806           Z.E.D.S. Rising   Bradley Botts          NaN        NaN
#
#       passive voice  all adverbs  ly-adverbs  non-ly-adverbs genre    year
# 4508            NaN          NaN         NaN             NaN    []  2020.0  \
# 5215            NaN          NaN         NaN             NaN    []  2014.0
# 7806            NaN          NaN         NaN             NaN    []  2016.0
#
#         author_clean               title_clean
# 4508   C C  Sommerly                Magic Lies
# 5215  C  J   Klinger  The Khruellian Encounter
# 7806   Bradley Botts           Z E D S  Rising

# %%
#Just grabbing the indices of the ones I don't need...
missing_prosecraft[(missing_prosecraft['genre'] == '[]') & (missing_prosecraft['year'].notna())].index
# Out:
# Index([4508, 5215, 7806], dtype='int64')

# %%
missing_prosecraft = missing_prosecraft.drop([4508, 5215, 7806])

# %%
missing_prosecraft.sample(5)
# Out:
#                                             title                    author
# 7890                        The Mind–Body Problem         Jonathan Westphal  \
# 17079  The Girl Who Could Move Sh*t With Her Mind              Jackson Ford
# 23412                            The Perfect Nine       Ngũgĩ wa Thiong’o
# 22557                            Minutes of Glory       Ngũgĩ wa Thiong’o
# 8468           The Love Songs of W. E. B. Du Bois  Honorée Fanonne Jeffers
#
#        total words  vividness  passive voice  all adverbs  ly-adverbs
# 7890           NaN        NaN            NaN          NaN         NaN  \
# 17079          NaN        NaN            NaN          NaN         NaN
# 23412          NaN        NaN            NaN          NaN         NaN
# 22557          NaN        NaN            NaN          NaN         NaN
# 8468           NaN        NaN            NaN          NaN         NaN
#
#        non-ly-adverbs                                              genre
# 7890              NaN  ['Philosophy', 'Nonfiction', 'Science', 'Psych...  \
# 17079             NaN  ['Science Fiction', 'Fantasy', 'Mystery', 'Fic...
# 23412             NaN  ['Fiction', 'Poetry', 'Africa', 'Mythology', '...
# 22557             NaN  ['Short Stories', 'Fiction', 'Africa', 'Kenya'...
# 8468              NaN                                                 []
#
#          year              author_clean
# 7890   2016.0         Jonathan Westphal  \
# 17079  2019.0              Jackson Ford
# 23412  2018.0          Ngugi wa Thiongo
# 22557  2019.0          Ngugi wa Thiongo
# 8468      NaN  Honoree Fanonne Jeffers
#
#                                      title_clean
# 7890                        The MindBody Problem
# 17079  The Girl Who Could Move Sht With Her Mind
# 23412                           The Perfect Nine
# 22557                           Minutes of Glory
# 8468          The Love Songs of W  E  B  Du Bois

# %% [markdown]
# Hmm... I've checked the URL of some of these and nothing seems to be unexpected! I'm not sure what's happening. Let's make a new function that just gives me the URLs.

# %%
def get_url(index):
    '''Given the cleaned title and author of a book, return the Prosecraft linguistic data'''
    
    #Copies the non-prosecraft columns of the original dataframe
    #row = missing_prosecraft[(missing_prosecraft['title_clean'] == title) & (missing_prosecraft['author_clean'] == author)]
    row = missing_prosecraft.loc[index]
    
    #Formats the URL
    title = row['title_clean'].replace(' ','-').lower()
    author = row['author_clean'].replace(' ','-').lower()
    URL = f"http://prosecraft.io/library/{author}/{title}"
        
    return URL

# %%
urls = missing_prosecraft.apply(lambda row: get_url(row.name), axis=1)

# %%
urls.iat[0]
# Out:
# 'http://prosecraft.io/library/edward-m--hallowell-and-john-j--ratey/adhd-2-0'

# %% [markdown]
# Aha! It looks like several of the URLs have two spaces where there should only be one! I've also found a few with a trailing space. Let's see what we can do.

# %%
missing_prosecraft.loc[:,'author_clean'] = missing_prosecraft['author_clean'].str.replace('  ',' ').str.strip()
missing_prosecraft.loc[:,'title_clean'] = missing_prosecraft['title_clean'].str.replace('  ',' ').str.strip()

# %% [markdown]
# Let's try another round!

# %%
new_df = missing_prosecraft.progress_apply(lambda row: get_prosecraft(row.name), axis=1)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 28/28 [03:01<00:00,  6.48s/it]

# %%
in_order = new_df[['title', 'author', 'total words', 'vividness', 'passive voice',
       'all adverbs', 'ly-adverbs', 'non-ly-adverbs', 'genre', 'year']]

# %%
len(in_order[in_order['vividness'].notnull()])
# Out:
# 19

# %%
merged = pd.concat([merged,in_order]).dropna(subset=['vividness'])
len(merged)
# Out:
# 24848

# %%
#merged.to_csv('no_null_prosecraft.csv')

# %%
missing_prosecraft = missing_prosecraft[in_order['vividness'].isna()]

# %%
missing_prosecraft
# Out:
#                                             title               author
# 1491                           Walk Through Walls    Marina Abramović  \
# 7890                        The Mind–Body Problem    Jonathan Westphal
# 14550                                  Belladonna        Daša Drndić
# 14708                       Blinded by the Lights       Jakub Żulczyk
# 15171                              Weep Not Child  Ngũgĩ wa Thiong’o
# 17079  The Girl Who Could Move Sh*t With Her Mind         Jackson Ford
# 20926                                        Mars          Asja Bakić
# 22557                            Minutes of Glory  Ngũgĩ wa Thiong’o
# 23412                            The Perfect Nine  Ngũgĩ wa Thiong’o
#
#        total words  vividness  passive voice  all adverbs  ly-adverbs
# 1491           NaN        NaN            NaN          NaN         NaN  \
# 7890           NaN        NaN            NaN          NaN         NaN
# 14550          NaN        NaN            NaN          NaN         NaN
# 14708          NaN        NaN            NaN          NaN         NaN
# 15171          NaN        NaN            NaN          NaN         NaN
# 17079          NaN        NaN            NaN          NaN         NaN
# 20926          NaN        NaN            NaN          NaN         NaN
# 22557          NaN        NaN            NaN          NaN         NaN
# 23412          NaN        NaN            NaN          NaN         NaN
#
#        non-ly-adverbs                                              genre
# 1491              NaN  ['Art', 'Nonfiction', 'Memoir', 'Biography', '...  \
# 7890              NaN  ['Philosophy', 'Nonfiction', 'Science', 'Psych...
# 14550             NaN  ['Fantasy', 'Romance', 'Young Adult', 'Mystery...
# 14708             NaN  ['Polish Literature', 'Fiction', 'Thriller', '...
# 15171             NaN                              ['Africa', 'Fiction']
# 17079             NaN  ['Science Fiction', 'Fantasy', 'Mystery', 'Fic...
# 20926             NaN  ['Nonfiction', 'Self Help', 'Psychology', 'Rel...
# 22557             NaN  ['Short Stories', 'Fiction', 'Africa', 'Kenya'...
# 23412             NaN  ['Fiction', 'Poetry', 'Africa', 'Mythology', '...
#
#          year       author_clean                                title_clean
# 1491   2016.0   Marina Abramovic                         Walk Through Walls
# 7890   2016.0  Jonathan Westphal                       The MindBody Problem
# 14550  2022.0        Dasa Drndic                                 Belladonna
# 14708  2014.0      Jakub Zulczyk                      Blinded by the Lights
# 15171  2005.0   Ngugi wa Thiongo                             Weep Not Child
# 17079  2019.0       Jackson Ford  The Girl Who Could Move Sht With Her Mind
# 20926  1992.0         Asja Bakic                                       Mars
# 22557  2019.0   Ngugi wa Thiongo                           Minutes of Glory
# 23412  2018.0   Ngugi wa Thiongo                           The Perfect Nine

# %% [markdown]
# Okay! Everyone left (except Jackson Ford and Jonathan Westphal, whose titles have mistreated special characters) has something in common--It turns out, with certain accented characters, prosecraft simply changes the letter into a space rather than the equivalent Latin character.

# %%
replacements['ũ'] = ' '
replacements['ĩ'] = ' '
replacements['Ż'] = ' '
replacements['ć'] = ' '

# %%
missing_prosecraft.loc[:,'title_clean'] = missing_prosecraft['title'].str.replace('.', ' ')\
                                        .str.replace(' - ', ' ').str.replace('-',' ')\
                                        .str.replace('(',' ').str.replace(')',' ').str.replace(',',' ')\
                                        .str.replace('*',' ').str.replace('–', ' ').str.replace('  ', ' ').str.strip()
missing_prosecraft.loc[:,'author_clean'] = missing_prosecraft['author'].str.replace('.', ' ')\
                                        .str.replace(' - ', ' ').str.replace('-',' ')\
                                        .str.replace('(',' ').str.replace(')',' ').str.replace(',',' ')\
                                        .str.replace('*',' ').str.replace('–', ' ').str.replace('  ', ' ').str.strip()

# %%
for before, after in replacements.items():
    missing_prosecraft.loc[:,'author_clean'] = missing_prosecraft['author_clean'].str.replace(before,after)
    missing_prosecraft.loc[:,'title_clean'] = missing_prosecraft['title_clean'].str.replace(before, after)
for before, after in more_replacements.items():
    missing_prosecraft.loc[:,'title_clean'] = missing_prosecraft.title_clean.str.replace(before,after)
    missing_prosecraft.loc[:,'author_clean'] = missing_prosecraft.author_clean.str.replace(before,after)

# %%
specials = set(missing_prosecraft.title_clean.sum()+missing_prosecraft.author_clean.sum()).difference(alphanum)
specials
# Out:
# {'’'}

# %%
#Just one special character left!
missing_prosecraft.loc[:,'author_clean'] = missing_prosecraft['author_clean'].str.replace('’','')

# %%
#Missed something the first time--some double spaces! 
missing_prosecraft.loc[:,'author_clean'] = missing_prosecraft['author_clean'].str.replace('  ',' ').str.strip()

# %% [markdown]
# Let's see if I got them all!

# %%
new_df = missing_prosecraft.progress_apply(lambda row: get_prosecraft(row.name), axis=1)
new_df
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 9/9 [01:01<00:00,  6.88s/it]
#                                             title               author
# 1491                           Walk Through Walls    Marina Abramović  \
# 7890                        The Mind–Body Problem    Jonathan Westphal
# 14550                                  Belladonna        Daša Drndić
# 14708                       Blinded by the Lights       Jakub Żulczyk
# 15171                              Weep Not Child  Ngũgĩ wa Thiong’o
# 17079  The Girl Who Could Move Sh*t With Her Mind         Jackson Ford
# 20926                                        Mars          Asja Bakić
# 22557                            Minutes of Glory  Ngũgĩ wa Thiong’o
# 23412                            The Perfect Nine  Ngũgĩ wa Thiong’o
#
#                                                    genre    year  total words
# 1491   ['Art', 'Nonfiction', 'Memoir', 'Biography', '...  2016.0     114836.0  \
# 7890   ['Philosophy', 'Nonfiction', 'Science', 'Psych...  2016.0      42756.0
# 14550  ['Fantasy', 'Romance', 'Young Adult', 'Mystery...  2022.0     113034.0
# 14708  ['Polish Literature', 'Fiction', 'Thriller', '...  2014.0     154979.0
# 15171                              ['Africa', 'Fiction']  2005.0      40939.0
# 17079  ['Science Fiction', 'Fantasy', 'Mystery', 'Fic...  2019.0     120300.0
# 20926  ['Nonfiction', 'Self Help', 'Psychology', 'Rel...  1992.0      33749.0
# 22557  ['Short Stories', 'Fiction', 'Africa', 'Kenya'...  2019.0      59166.0
# 23412  ['Fiction', 'Poetry', 'Africa', 'Mythology', '...  2018.0      21807.0
#
#        vividness  passive voice  all adverbs  ly-adverbs  non-ly-adverbs
# 1491       41.30           7.17         3.31        0.97            2.34
# 7890       27.19           8.97         3.46        1.37            2.09
# 14550      54.22           5.09         2.53        0.87            1.66
# 14708      52.61           7.58         3.17        0.96            2.21
# 15171      31.27           9.94         3.20        0.87            2.34
# 17079      50.38           9.20         2.87        0.88            1.99
# 20926      43.13           9.43         3.69        1.53            2.15
# 22557      42.09           7.47         3.36        1.04            2.32
# 23412      61.12           5.61         2.35        0.56            1.79

# %% [markdown]
# SUCCESS!

# %%
in_order = new_df[['title', 'author', 'total words', 'vividness', 'passive voice',
       'all adverbs', 'ly-adverbs', 'non-ly-adverbs', 'genre', 'year']]

# %%
merged = pd.concat([merged,in_order]).dropna(subset=['vividness'])

# %%
len(merged)
# Out:
# 24857

# %%
merged.to_csv('no_null_prosecraft.csv')
